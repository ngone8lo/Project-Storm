# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# # Appendices

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('StormDatasetFinal.csv')

# %% [markdown]
# ### Describe Numerical Variables

# %%
df.describe()
# Out:
#                 Lat           Lon          Wind      Pressure  TimeSinceStart  \
# count  10448.000000  10448.000000  10448.000000  10448.000000    1.044800e+04
# mean      26.339333    -59.491049     54.967171    994.539338    4.416503e+05
# std       10.248518     21.845103     27.678624     18.355330    3.635768e+05
# min        7.500000   -120.500000     17.000000    908.000000    0.000000e+00
# 25%       17.700000    -76.590250     35.000000    988.000000    1.620000e+05
# 50%       26.087000    -60.439500     46.000000   1002.000000    3.456000e+05
# 75%       33.100000    -42.462750     69.000000   1007.000000    6.372000e+05
# max       69.000000      5.300000    184.000000   1021.000000    2.052000e+06
#
#            Duration      StartLat      StartLon     StartWind  StartPressure  \
# count  1.044800e+04  10448.000000  10448.000000  10448.000000   10448.000000
# mean   8.829572e+05     18.389644    -51.219698     30.790295    1008.870310
# std    4.439362e+05      8.336057     24.303520      8.434464       3.536614
# min    6.480000e+04      7.500000    -97.400000     17.000000     988.000000
# 25%    5.400000e+05     12.000000    -74.825000     23.000000    1007.000000
# 50%    8.640000e+05     15.200000    -46.400000     29.000000    1009.000000
# 75%    1.144800e+06     25.100000    -32.000000     35.000000    1010.000000
# max    2.052000e+06     41.200000     -9.600000     63.000000    1021.000000
#
#              EndLat        EndLon       EndWind   EndPressure       MinWind  \
# count  10448.000000  10448.000000  10448.000000  10448.000000  10448.000000
# mean      38.184475    -52.622621     37.915582   1000.966214     27.310490
# std       12.354598     27.904712     15.242859     12.575154      7.419462
# min        9.100000   -120.500000     17.000000    960.000000     17.000000
# 25%       30.700000    -73.300000     29.000000    995.000000     23.000000
# 50%       38.200000    -52.900000     35.000000   1005.000000     29.000000
# 75%       45.800000    -30.900000     46.000000   1010.000000     29.000000
# max       69.000000      5.300000     98.000000   1020.000000     58.000000
#
#             MaxWind   MinPressure   MaxPressure
# count  10448.000000  10448.000000  10448.000000
# mean      91.314319    973.897109   1010.346478
# std       38.792699     27.046395      3.442950
# min       29.000000    908.000000   1001.000000
# 25%       58.000000    955.000000   1008.000000
# 50%       86.000000    979.000000   1010.000000
# 75%      115.000000    998.000000   1012.000000
# max      184.000000   1012.000000   1021.000000

# %% [markdown]
# ### Describe Object Variables

# %%
df.describe(include=np.object)
# Out:
#            NameYear  Season       StormType MaxStrength StartStormType  \
# count         10448   10448           10425       10448          10448
# unique          175       4              14           5              7
# top     Nadine_2012  Autumn  Tropical Storm   Hurricane   Tropical Low
# freq            191    6369            3760        6347           4996
#
#          EndStormType
# count           10365
# unique              7
# top     Extratropical
# freq             4857

# %% [markdown]
# ### Correlation Matrix Plot

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
df.hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8);
